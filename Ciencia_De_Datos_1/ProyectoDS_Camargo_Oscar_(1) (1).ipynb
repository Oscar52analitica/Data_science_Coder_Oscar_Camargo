# %% [markdown]
# AUTOR:
# Oscar Orlando Camargo Vargas
#
# ## Análisis de impacto del precio de fabricaicón de diferentes modelos de autos según su año de fabricación: Estudio de Datos

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:17px">
#
#
#
# <h3 align="left"><font color=#4e8c4ee>📝 Objetivos:</font></h3><br>
#
# 1. Validar las hipótesis formuladas a través de análisis estadísticos y representaciones gráficas.
# 2. Descubrir patrones y tendencias dentro del conjunto de datos.
# 3. Crear un modelo predictivo para calcular la relación entre el año de fabriación de un auto y su precio.
#
# ### <h3 align="left"><font color=#4e8c4ee>Abstarct:</font></h3><br>
#
#  Este proyecto se centra en el análisis  de los datos el csv Cars_Database, examinando diversas características como:
# - Precio.
# - Año de Fabricación.
# - Tamaño de Motor.
# - Consumo por millas.
# - Millaje.
# - Gasto de combustible.
#
#
# ### <h3 align="left"><font color=#4e8c4ee> Hipótesis:
# </font></h3><br>
#
# Basándonos en un análisis previo del dataset, planteamos las siguientes Hipotesis.
#
# - Relación entre año y precio: ¿Cómo afecta el año de fabricación al precio de los automóviles? Hipótesis: Los autos más nuevos tienden a ser más caros.
# - Impacto de la transmisión en el precio: ¿Es la transmisión automática más cara que la manual?
# - Influencia del tipo de combustible: ¿Los autos que utilizan combustible más eficiente tienen un precio más alto?
# - Costo por milla vs. Años de circulación: ¿Los autos que han circulado más años tienen un costo por milla más bajo?
#
#
# ###  <h3 align="left"><font color=#4e8c4ee>Impacto:
# </font></h3><br>
#
#
# - Determinar los factores que influyen en el precio de un vehiculo.
# - Crear informes para la toma de desiciones a la hora de la compra de un vehiculo si es mas combeniente uno sobre otro analisando diferentes variables.
# - Construir un modelo que permita comparar diferentes variables a una persona a fin de simplificar conceptos y predecir cual vehiculo es mas combeniente para difernetes presupuestos.

# %% [markdown]
# # <font color=#4e8c4ee> Contenido de el Csv
#
# - El file continene 15 Columnas distribuidas de la siguiente manera:
# -Primiry_key: LLave que permite identificar cada resgitro unico segun marca del auto.
# - Model: Modelo del auto segun su fabricante.
# - Year: Año de Fabricacion.
# - Price: Precio de venta del auto.
# - transmission: Tipo de transmision del vehiculo(Automatica, manual, semi automatica)
# - Millage: Cantidad de millas que tienen el motor del vehiculo a la fecha.
# - FuelType: Tipo de Combustile(Gasolina, Diesel, Electrico, Hibrido,Gas)
# - Tax: Impuesto que paga el vehiculo.
# - Mpg: Consumo de galon de combustible por milla de desplazamineto.
# - ngineSize: Tamaño del motor del vehiculo.
# - Make: Fabricante del vehiculo( Audi, BMW, ETC.).
# - Años de circulacion: Años de circulacion del vehiculo a la fecha.
# - Costo por milla: Precio de combistible segun el millage del vehiculo.
# - Consumo de combustible por año(Millas por galon): Consumo anual de combustible del vehiculo segun los datos registrados en la BD.
# - Tax_Bracket: Rango de impuestos segun categorias(Alto, Medio, Bajo).

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b> ⚙️ Contenido del Proyecto⚙️</b></div>

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:16px">
#
# <h3 align="left"><font color=#4e8c4ee> Tabla de contenido.
# </font></h3><br>
#
# 1. <b>📚 Importación de Bibliotecas:</b> - Para realizar <b>manipulación de datos, visualización y construcción de modelos.</b><br>
#
# 2. <b>⏳ Carga del Conjunto de Datos:</b> - Cargar el conjunto de datos en una <b>estructura de datos adecuada utilizando pandas.</b><br>
#
# 3. <b>🧠 Comprensión Básica de los Datos:</b> - Generar información básica sobre los datos.<br>
#
# 4. <b>🧹 Limpieza de Datos:</b> - Para <b>limpiar, transformar y reestructurar</b> los datos con el fin de hacerlos adecuados para el análisis.<br>
#
# 5. <b>📊 Análisis Exploratorio de Datos:</b> - Para identificar <b>tendencias, patrones y relaciones</b> entre las variables.<br>
#
# 6. <b>📈 Selección de Características:</b> - Para identificar las <b>características más relevantes</b> para la construcción del modelo.<br>
#
# 7. <b>⚙️ Preprocesamiento de Datos:</b> - Para transformar los datos y crear un modelo más preciso y robusto.<br>
#
# 8. <b>🎯 Construcción del Modelo:</b> - Para construir <b>modelos predictivos</b> utilizando varios algoritmos.<br>
#
# 9. <b>⚡️ Evaluación del Modelo:</b> - Para analizar el rendimiento del modelo utilizando métricas.<br>
#
# 10. <b>🍀 Apilamiento de Modelos:</b> - Para desarrollar un modelo apilado utilizando los mejores modelos de rendimiento.<br>
#
# 11. <b>🎈 Conclusión:</b> - Concluir el proyecto resumiendo los <b>hallazgos clave.</b><br>
#
# </div>
# </div>

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b>📚 1. Importación de Bibliotecas:</b></div>

# %%
# Manipulación de datos y operaciones numéricas

import pandas as pd  # Manejo de datos en formato tabular (DataFrames)
import numpy as np  # Operaciones numéricas y manejo de arrays

# Visualización de datos
import matplotlib.pyplot as plt  # Creación de gráficos y visualizaciones básicas
import seaborn as sns  # Visualización avanzada, basada en matplotlib con temas y gráficos predeterminados

# Preprocesamiento de datos
from sklearn.impute import SimpleImputer  # Imputación de valores faltantes en el conjunto de datos
from sklearn.preprocessing import LabelEncoder  # Codificación de variables categóricas en valores numéricos

# Modelado y selección de modelos
from sklearn.model_selection import train_test_split  # División del conjunto de datos en entrenamiento y prueba

# Algoritmos de regresión
from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV  # Regresiones lineales y regularizadas
from sklearn.neighbors import KNeighborsRegressor as KNN  # Algoritmo de regresión basado en vecinos más cercanos
from xgboost import XGBRegressor  # Algoritmo de regresión basado en boosting

# Evaluación del modelo
from sklearn.metrics import mean_squared_error, r2_score  # Métricas de evaluación para modelos de regresión (error cuadrático medio y coeficiente de determinación)

# Sistema operativo
import os  # Interacción con el sistema operativo, manejo de rutas, archivos, etc.
import matplotlib.pyplot as plt

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b>⏳ 2. Carga del conjunto de Datos ⏳</b></div>

# %%
# Leer el archivo de Excel 'Cars_Database.xlsx'
df_cars= pd.read_excel('Cars_Database.xlsx')

# %%
df_cars.head().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b>🧠 3. Entendimiento de la Data 🧠</b></div>

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b>  3.1. Verificacndo las dimensiones del Dataset.

# %%
df_cars.shape
# Out:
# (72435, 15)

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72435 entries, 0 to 72434
# Data columns (total 15 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Primiry_key                                       72435 non-null  object
#  1   model                                             72435 non-null  object
#  2   year                                              72435 non-null  int64
#  3   price                                             72435 non-null  int64
#  4   transmission                                      72435 non-null  object
#  5   mileage                                           72435 non-null  int64
#  6   fuelType                                          72435 non-null  object
#  7   tax                                               72435 non-null  int64
#  8   mpg                                               72435 non-null  int64
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Total de registros **72435 filas en el dataset.
# * Total de ***17 columnas en el dataset.

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b> 3.2. Generalidades de la data.

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
# - 6 Columas con datos categoricos.
# - 9 Columnas con datos Númericos.

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b>3.3 Procesabdo Valores faltantes.

# %%
null_df = df_cars.isnull().sum().to_frame().rename(columns={0: "Total de valores faltantes"})
null_df["% de valores faltantes"] = round(100 * null_df["Total de valores faltantes"] / len(df_cars), 2)
null_df = null_df.sort_values(by="% de valores faltantes", ascending=False)
print(null_df)
# Out:
#                                                   Total de valores faltantes  \
# Primiry_key                                                                0
# model                                                                      0
# year                                                                       0
# price                                                                      0
# transmission                                                               0
# mileage                                                                    0
# fuelType                                                                   0
# tax                                                                        0
# mpg                                                                        0
# engineSize                                                                 0
# Make                                                                       0
# ...

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b> 3.4.Verificando la exixtenciia de valores duplicados especificos en el dataset.

# %%
print("Is there any Duplicate Records => ",df_cars.duplicated().any())
print("-"*42)
print("Total Duplicate Records present is =>",df_cars[df_cars.duplicated()==True].shape[0])
# Out:
# Is there any Duplicate Records =>  True
# ------------------------------------------
# Total Duplicate Records present is => 844

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# * Se puede inferir que existe una columna que tiene datos nulos la cual es consumo de combustible por año
# * Se muestra que existen 844 valores duplicados en el dataframe

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b>3.5. Eliminando Duplicados.

# %%
# df_cars.drop_duplicates(inplace=True) para este caso particular no voy a remover los datos duplicados

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b> 3.6. Analíss descrictivo estadistico de variales númericas.

# %%
df_cars.describe().T.style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ### 3.6.1 Algunas inferencias de nuestro estudio de la variable price Y otras variables.
#
#
# - Min: 495 (USD)
# - Max: 145,000 (USD)
# - Los datos están en un rango de entre 1996 y 2020
# - El millage va desde 1 milla hasta 323,000 millas

# %% [markdown]
#
# 4. <b>🧹 Limpieza de Datos:</b> - Para <b>limpiar, transformar y reestructurar</b> los datos con el fin de hacerlos adecuados para el análisis.<br>
#
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b> 🧹 4. Limpieza de Datos:</b></div>

# %%
# Ubicar filas con al menos un valor 0 o NaN
columnas_cero = (df_cars== 0).any()
columnas_nan =  df_cars.isna().any()


print("Filas con valor 0 o NaN:")
print(columnas_cero)
print(columnas_nan)
# Out:
# Filas con valor 0 o NaN:
# Primiry_key                                         False
# model                                               False
# year                                                False
# price                                               False
# transmission                                        False
# mileage                                             False
# fuelType                                            False
# tax                                                  True
# mpg                                                  True
# engineSize                                           True
# Make                                                False
# Años de circulacion                                 False
# Costo por milla                                     False
# Consumo de combustible por año(Millas por galon)     True
# Tax_Bracket                                         False
# dtype: bool
# ...

# %% [markdown]
# ### 4.1 Para  que el analisis sea completo se deben buscar en las culumnas valores en en cero o en NaN para ello se aplica el codigo visto en clase

# %%
# Reemplazar valores NaN con la media en las columnas de interés
columns_to_fill_na = ['tax', 'mpg', 'engineSize', 'Consumo de combustible por año(Millas por galon)']

for col in columns_to_fill_na:
    df_cars[col].fillna(df_cars[col].mean(), inplace=True)

# Imprimir para verificar el cambio
print(df_cars[columns_to_fill_na])
# Out:
#        tax  mpg  engineSize  Consumo de combustible por año(Millas por galon)
# 0      150   55         1.4                                             286.0
# 1       20   64         2.0                                             566.0
# 2       30   55         1.4                                             544.0
# 3      145   67         2.0                                             387.0
# 4      145   50         1.0                                              40.0
# ...    ...  ...         ...                                               ...
# 72430    0   78         1.6                                             332.0
# 72431   30   66         1.7                                             902.0
# 72432   20   60         1.0                                             230.0
# 72433  145   45         1.6                                             518.0
# 72434  125   58         1.7                                             198.0
#
# [72435 rows x 4 columns]
# ...

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b> 5.📊 EDA Analisis exploratorio de datos.📊</b></div>

# %% [markdown]
# Vamos a empezar con la descripcion del dataframe para conocer su estructura

# %%
df_cars.head().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# ...

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72435 entries, 0 to 72434
# Data columns (total 15 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Primiry_key                                       72435 non-null  object
#  1   model                                             72435 non-null  object
#  2   year                                              72435 non-null  int64
#  3   price                                             72435 non-null  int64
#  4   transmission                                      72435 non-null  object
#  5   mileage                                           72435 non-null  int64
#  6   fuelType                                          72435 non-null  object
#  7   tax                                               72435 non-null  int64
#  8   mpg                                               72435 non-null  int64
# ...

# %% [markdown]
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b> 5.1. Visualizando los valores clave del analisís.

# %%
df_cars.describe().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# Se plantea una grafica para ver la dsitribucion de los datos respecto a el Precio comparado con los años que es la hipoteis planteada Solo es a modo exploratorio

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df_cars['year'], y=df_cars['price'], color='blue', alpha=0.6)
plt.title('Relación entre Año y Precio', fontweight='bold', size=18)
plt.xlabel('Año', size=14)
plt.ylabel('Precio', size=14)
plt.tight_layout()
plt.show()

# %%
df_cars.hist(figsize=(15,13),bins=50)
plt.show()

# %% [markdown]
# ## <div style="text-align: left; background-color:#CFD9F1 ; font-family: Trebuchet MS; color: #0A3399; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green;"> 2. Visualizando atributo "Año" </div>

# %% [markdown]
# Ahora se realizara la Gaficación de una comparativa entre mi variable Price con las otras variables numericas a fin de conocer visualizar la relación que existe entre ellas

# %%
def plot_price_year():
    plt.figure(figsize=(12, 6))
    sns.scatterplot(x=df_cars['year'], y=df_cars['price'], color="purple", alpha=0.7, s=100)
    plt.title("Relación entre Year y Price", fontweight="bold", fontsize=18)
    plt.xlabel("Year", fontsize=14)
    plt.ylabel("Price", fontsize=14)
    plt.gca().set_facecolor('#f7f7f7')  # Fondo suave
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

plot_price_year()

# %% [markdown]
# ## <div style="text-align: left; background-color:#CFD9F1 ; font-family: Trebuchet MS; color: #0A3399; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green;"> 3. Visualizando atributo "Millage". </div>

# %%
def plot_price_mileage():
    plt.figure(figsize=(12, 6))
    sns.scatterplot(x=df_cars['mileage'], y=df_cars['price'], color="blue", alpha=0.7, s=100)
    plt.title("Relación entre Mileage y Price", fontweight="bold", fontsize=18)
    plt.xlabel("Mileage", fontsize=14)
    plt.ylabel("Price", fontsize=14)
    plt.gca().set_facecolor('#f7f7f7')  # Fondo suave
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

plot_price_mileage()

# %% [markdown]
# ## <div style="text-align: left; background-color:#CFD9F1 ; font-family: Trebuchet MS; color: #0A3399; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green;"> 4. Visualizando atributo "Tax". </div>

# %%
def plot_price_tax():
    plt.figure(figsize=(12, 6))
    sns.scatterplot(x=df_cars['tax'], y=df_cars['price'], color="green", alpha=0.7, s=100)
    plt.title("Relación entre Tax y Price", fontweight="bold", fontsize=18)
    plt.xlabel("Tax", fontsize=14)
    plt.ylabel("Price", fontsize=14)
    plt.gca().set_facecolor('#f7f7f7')  # Fondo suave
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

plot_price_tax()

# %% [markdown]
# ## <div style="text-align: left; background-color:#CFD9F1 ; font-family: Trebuchet MS; color: #0A3399; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green;"> 5. Visualizando atributo "MPG". </div>

# %%
def plot_price_mpg():
    plt.figure(figsize=(12, 6))
    sns.scatterplot(x=df_cars['mpg'], y=df_cars['price'], color="orange", alpha=0.7, s=100)
    plt.title("Relación entre MPG y Price", fontweight="bold", fontsize=18)
    plt.xlabel("MPG", fontsize=14)
    plt.ylabel("Price", fontsize=14)
    plt.gca().set_facecolor('#f7f7f7')  # Fondo suave
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

plot_price_mpg()

# %% [markdown]
# ## <div style="text-align: left; background-color:#CFD9F1 ; font-family: Trebuchet MS; color: #0A3399; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green;"> 6. Visualizando atributo "engineSize". </div>

# %%
def plot_price_enginesize():
    plt.figure(figsize=(12, 6))
    sns.scatterplot(x=df_cars['engineSize'], y=df_cars['price'], color="red", alpha=0.7, s=100)
    plt.title("Relación entre Engine Size y Price", fontweight="bold", fontsize=18)
    plt.xlabel("Engine Size", fontsize=14)
    plt.ylabel("Price", fontsize=14)
    plt.gca().set_facecolor('#f7f7f7')  # Fondo suave
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

plot_price_enginesize()

# %% [markdown]
# ## <div style="text-align: left; background-color:#CFD9F1 ; font-family: Trebuchet MS; color: #0A3399; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green;"> 7. Visualizando atributo "Años de circulación". </div>

# %%
# Limpiar los nombres de las columnas eliminando espacios extra
df_cars.columns = df_cars.columns.str.strip()

# Ahora, el código para el gráfico con 'Años de circulación'
def plot_price_years_on_road():
    plt.figure(figsize=(12, 6))
    sns.scatterplot(x=df_cars['Años de circulacion'], y=df_cars['price'], color="pink", alpha=0.7, s=100)
    plt.title("Relación entre Años de Circulación y Price", fontweight="bold", fontsize=18)
    plt.xlabel("Años de Circulación", fontsize=14)
    plt.ylabel("Price", fontsize=14)
    plt.gca().set_facecolor('#f7f7f7')  # Fondo suave
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

plot_price_years_on_road()

# %% [markdown]
# ## <div style="text-align: left; background-color:#CFD9F1 ; font-family: Trebuchet MS; color: #0A3399; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green;"> 8. Visualizando Atributo "costo por milla". </div>

# %%
# Limpiar los nombres de las columnas eliminando espacios extra
df_cars.columns = df_cars.columns.str.strip()

# Ahora, el código para el gráfico con 'Costo por milla'
def plot_price_cost_per_mile():
    plt.figure(figsize=(12, 6))
    sns.scatterplot(x=df_cars['Costo por milla'], y=df_cars['price'], color="cyan", alpha=0.7, s=100)
    plt.title("Relación entre Costo por Milla y Price", fontweight="bold", fontsize=18)
    plt.xlabel("Costo por Milla", fontsize=14)
    plt.ylabel("Price", fontsize=14)
    plt.gca().set_facecolor('#f7f7f7')  # Fondo suave
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

plot_price_cost_per_mile()

# %% [markdown]
# ## <div style="text-align: left; background-color:#CFD9F1 ; font-family: Trebuchet MS; color: #0A3399; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green;"> 9. Visualizando atributo "consumo de combustible por año". </div>

# %%
# Limpiar los nombres de las columnas eliminando espacios extra
df_cars.columns = df_cars.columns.str.strip()

# Verificar los nombres de las columnas para asegurarse de que el nombre es correcto
print(df_cars.columns)

# Ahora, el código para el gráfico con 'Consumo de combustible por año'
def plot_price_fuel_consumption():
    plt.figure(figsize=(12, 6))
    sns.scatterplot(x=df_cars['Consumo de combustible por año(Millas por galon)'], y=df_cars['price'], color="teal", alpha=0.7, s=100)
    plt.title("Relación entre Consumo de Combustible por Año y Price", fontweight="bold", fontsize=18)
    plt.xlabel("Consumo de Combustible por Año (MPG)", fontsize=14)
    plt.ylabel("Price", fontsize=14)
    plt.gca().set_facecolor('#f7f7f7')  # Fondo suave
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

plot_price_fuel_consumption()
# Out:
# Index(['Primiry_key', 'model', 'year', 'price', 'transmission', 'mileage',
#        'fuelType', 'tax', 'mpg', 'engineSize', 'Make', 'Años de circulacion',
#        'Costo por milla', 'Consumo de combustible por año(Millas por galon)',
#        'Tax_Bracket'],
#       dtype='object')

# %% [markdown]
# ## Box plot.

# %%
# Corregir el nombre de la columna eliminando el espacio extra al final
df_cars.columns = df_cars.columns.str.strip()  # Elimina espacios innecesarios en los nombres de las columnas

# Lista de las variables que quieres analizar
variables = ['year', 'mileage', 'tax', 'mpg', 'engineSize', 'Años de circulacion', 'Costo por milla', 'Consumo de combustible por año(Millas por galon)']

# Crear la figura y los subgráficos
fig, axes = plt.subplots(1, len(variables), figsize=(20,6))

# Dibujar un boxplot para cada variable
for ax, variable in zip(axes, variables):
    sns.boxplot(y=df_cars[variable], ax=ax)
    ax.set_title(f"Distribución de {variable}", fontsize=12)

# Ajustar el layout para que no se superpongan
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Matriz de Correlación.

# %%
# Eliminar espacios adicionales en los nombres de las columnas
df_cars.columns = df_cars.columns.str.strip()

# Lista de variables numéricas que deseas analizar
variables = ['year', 'mileage', 'tax', 'mpg', 'engineSize', 'Años de circulacion', 'Costo por milla', 'Consumo de combustible por año(Millas por galon)']

# Seleccionar las columnas que están en la lista de variables
df_numeric = df_cars[variables]

# Calcular la matriz de correlación
corr = df_numeric.corr()

# Crear el mapa de calor con el color especificado
plt.figure(figsize=(13.5, 10))
sns.heatmap(corr, annot=True, fmt=".2g", cmap='YlOrRd_r', cbar=True, square=True, linewidths=0.5)

# Título y ajustes estéticos
plt.title("Correlation of Selected Variables", fontweight="black", size=25, pad=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Datos Categoricos

# %%
df_cars.describe(include='object')
# Out:
#                                 Primiry_key    model transmission fuelType  \
# count                                 72435    72435        72435    72435
# unique                                69055      146            4        5
# top     BMW_ X2_2019_Automatic_123_Petrol_2   Fiesta       Manual   Petrol
# freq                                     23     6556        43021    40370
#
#          Make Tax_Bracket
# count   72435       72435
# unique      7           3
# top      Ford       Medio
# freq    17964       50525

# %%
df_cars['Primiry_key'].value_counts()
# Out:
# Primiry_key
# BMW_ X2_2019_Automatic_123_Petrol_2                23
# vw_ Polo_2019_Manual_5000_Petrol_1                 20
# BMW_ 2 Series_2019_Manual_123_Petrol_1,5           19
# vw_ Up_2020_Manual_100_Petrol_1                    16
# BMW_ X2_2019_Automatic_123_Diesel_2                15
#                                                    ..
# Ford_ Fiesta_2018_Manual_6203_Petrol_1              1
# Ford_ Fiesta_2018_Manual_12135_Petrol_1             1
# Ford_ Fiesta_2013_Manual_45187_Petrol_1             1
# Ford_ EcoSport_2018_Semi-Auto_17461_Petrol_1        1
# Hyundai_ Tucson_2016_Automatic_11472_Diesel_1,7     1
# Name: count, Length: 69055, dtype: int64

# %%
df_cars['model'].value_counts()
# Out:
# model
# Fiesta             6556
# Golf               4863
# Focus              4588
# Polo               3287
# 3 Series           2443
#                    ...
# RS7                   1
# Escort                1
# Accent                1
# Transit Tourneo       1
# Amica                 1
# Name: count, Length: 146, dtype: int64

# %%
df_cars['transmission'].value_counts()
# Out:
# transmission
# Manual       43021
# Semi-Auto    15364
# Automatic    14046
# Other            4
# Name: count, dtype: int64

# %%
df_cars['fuelType'].value_counts()
# Out:
# fuelType
# Petrol      40370
# Diesel      28918
# Hybrid       2903
# Other         239
# Electric        5
# Name: count, dtype: int64

# %%
df_cars['Make'].value_counts()
# Out:
# Make
# Ford       17964
# vw         15157
# BMW        10781
# audi       10668
# toyota      6738
# skoda       6267
# Hyundai     4860
# Name: count, dtype: int64

# %%
df_cars['Tax_Bracket'].value_counts()
# Out:
# Tax_Bracket
# Medio    50525
# Bajo     18366
# Alto      3544
# Name: count, dtype: int64

# %%
# Distribución de precios según la transmisión (automática o manual)

plt.figure(figsize=(8, 6))
sns.boxplot(x='transmission', y='price', data=df_cars, palette='Set2')
plt.title('Distribución de Precios según Transmisión')
plt.xlabel('Transmisión')
plt.ylabel('Precio')
plt.show()
# Out:
# <ipython-input-34-1e7a481e063b>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='transmission', y='price', data=df_cars, palette='Set2')

# %%
# Precio promedio por año POR fabricante

plt.figure(figsize=(14, 8))
sns.barplot(x='Make', y='price', data=df_cars, estimator=lambda x: sum(x) / len(x))
plt.title('Precio Promedio por Fabricante')
plt.xlabel('Fabricante')
plt.ylabel('Precio Promedio')
plt.xticks(rotation=45)
plt.show()

# %%
#Relación entre Año y Precio

plt.figure(figsize=(12, 6))
sns.scatterplot(x='year', y='price', hue='Make', data=df_cars)
sns.lineplot(x='year', y='price', hue='Make', data=df_cars, ci=None, estimator='mean', marker='o')
plt.title('Relación entre Año y Precio por Fabricante')
plt.xlabel('Año')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-36-9e11515f373c>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='year', y='price', hue='Make', data=df_cars, ci=None, estimator='mean', marker='o')

# %%
#  Tendencias de Precio a lo Largo del Tiempo por Fabricante:

plt.figure(figsize=(14, 8))
sns.lineplot(x='year', y='price', hue='Make', data=df_cars, marker='o')
plt.title('Tendencia de Precios a lo Largo del Tiempo por Fabricante')
plt.xlabel('Año')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b> 6. Preprocesamiento📊</b></div>

# %%
# label encoder para la categoricas
column= ['Primiry_key','model', 'transmission', 'fuelType', 'Make', 'Tax_Bracket']
df_cars[column] = df_cars[column].apply(LabelEncoder().fit_transform)

# %%
# elimino el id Primiry_Key
df_cars.drop('Primiry_key',axis=1,inplace=True)

# %%
df_cars.head()
# Out:
#    model  year  price  transmission  mileage  fuelType  tax  mpg  engineSize  \
# 0      8  2017  12500             1    15735         4  150   55         1.4
# 1     13  2016  16500             0    36203         0   20   64         2.0
# 2      8  2016  11000             1    29946         4   30   55         1.4
# 3     11  2017  16800             0    25952         0  145   67         2.0
# 4     10  2019  17300             1     1998         4  145   50         1.0
#
#    Make  Años de circulacion  Costo por milla  \
# 0     3                    7         0.794407
# 1     3                    8         0.455763
# 2     3                    8         0.367328
# 3     3                    7         0.647349
# 4     3                    5         8.658659
#
#    Consumo de combustible por año(Millas por galon)  Tax_Bracket
# 0                                             286.0            2
# 1                                             566.0            1
# ...

# %%
# Creación de la matriz de correlación
correlation_matrix = df_cars.corr()
# Visualización de la matriz de correlación
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b> 7. Modelado 📊</b></div>

# %%
# Cargar los datos
X = df_cars.drop(['price'],axis=1)
y = df_cars['price']

# %%
# split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=16)

print('x_train size',X_train.shape)
print('y_train size',y_train.shape)
print('x_test size',X_test.shape)
print('y_test size',y_test.shape)
# Out:
# x_train size (50704, 13)
# y_train size (50704,)
# x_test size (21731, 13)
# y_test size (21731,)

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b> 8. Hiperparametros📊</b></div>

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor

# Ridge Regression
ridge_params = {'alpha': [0.01, 0.1, 1, 10, 100]}
ridge_grid = GridSearchCV(Ridge(), ridge_params, cv=5, scoring='r2')
ridge_grid.fit(X_train, y_train)
print("Mejor parámetro para Ridge:", ridge_grid.best_params_)

# Lasso Regression
lasso_params = {'alpha': [0.01, 0.1, 1, 10, 100]}
lasso_grid = GridSearchCV(Lasso(), lasso_params, cv=5, scoring='r2')
lasso_grid.fit(X_train, y_train)
print("Mejor parámetro para Lasso:", lasso_grid.best_params_)

# KNN Regressor
knn_params = {'n_neighbors': range(1, 30)}
knn_grid = GridSearchCV(KNeighborsRegressor(), knn_params, cv=5, scoring='r2')
knn_grid.fit(X_train, y_train)
print("Mejor parámetro para KNN:", knn_grid.best_params_)

# XGBoost Regressor
xgb_params = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7]
}
xgb_random = RandomizedSearchCV(XGBRegressor(), xgb_params, cv=5, scoring='r2', n_iter=10, random_state=42)
xgb_random.fit(X_train, y_train)
print("Mejor parámetro para XGBoost:", xgb_random.best_params_)
# Out:
# Mejor parámetro para Ridge: {'alpha': 1}
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.775e+11, tolerance: 3.445e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.849e+11, tolerance: 3.490e+08
#   model = cd_fast.enet_coordinate_descent(
# ...

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><font color=#4e8c4ee><b> 9. Regresión Lineal 📊</b></div>

# %%
# instanciamos el modelo
model=LinearRegression()

# %%
# entranamos
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# prediccion
y_pred = model.predict(X_test)

# %%
# metrica R2
r2_rl = r2_score(y_test, y_pred)
r2_rl
# Out:
# 0.7268182414682014

# %% [markdown]
# ## KNN

# %%
# instanciamos el modelo
model = KNN(n_neighbors=5,weights="uniform",metric="manhattan")

# %%
# entranamos
model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(metric='manhattan')

# %%
# prediccion
y_pred = model.predict(X_test)

# %%
# metrica R2
r2_knn = r2_score(y_test, y_pred)
r2_knn
# Out:
# 0.6567302230839798

# %% [markdown]
# ## XGBoost

# %%
# instanciamos el modelo
model = XGBRegressor(n_estimators= 2000 , max_depth= 7 , learning_rate = 0.01)

# %%
# entranamos
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=2000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
# prediccion
y_pred = model.predict(X_test)

# %%
# metrica R2
r2_xgb = r2_score(y_test, y_pred)
r2_xgb
# Out:
# 0.9887529863987249

# %% [markdown]
# ## Resultados del Test

# %%
print("Algoritmo Regresión Lineal " + str(round(r2_rl, 4)))
print("Algoritmo KNN " + str(round(r2_knn, 4)))
print("Algoritmo XGB " + str(round(r2_xgb, 4)))
# Out:
# Algoritmo Regresión Lineal 0.7268
# Algoritmo KNN 0.6567
# Algoritmo XGB 0.9888

# %% [markdown]
# El mejor modelo fue el XGB

# %% [markdown]
# Graficos de analisis

# %%
# Gráfico de dispersión
plt.figure(figsize=(10, 6))
sns.scatterplot(x='year', y='price', data=df_cars, hue='Make', alpha=0.7)
plt.title('Relación entre Año y Precio de los Vehículos')
plt.xlabel('Año')
plt.ylabel('Precio')
plt.grid(True)
plt.show()

# Gráfico de línea
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='price', data=df_cars, ci=None)
plt.title('Tendencia de Precios a lo Largo del Tiempo')
plt.xlabel('Año')
plt.ylabel('Precio Promedio')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-59-21e8b126ea36>:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='year', y='price', data=df_cars, ci=None)

# %% [markdown]
# **Resultado**
#
# Relación Directa:  los gráficos muestran que los autos más nuevos tienden a tener precios más altos, esto confirmaría la hipótesis de que el año de fabricación es un factor importante en la determinación del precio.
#
# Variabilidad por Marca: Al segmentar por marca, se sabe  que algunas marcas retienen mejor su valor con el tiempo que otras.

# %% [markdown]
# Respecto a los automaticos y manuales:

# %%
# Gráfico de caja (Boxplot)
plt.figure(figsize=(10, 6))
sns.boxplot(x='transmission', y='price', data=df_cars, palette='Set2')
plt.title('Distribución de Precios según Tipo de Transmisión')
plt.xlabel('Transmisión')
plt.ylabel('Precio')
plt.show()

# Gráfico de barras (Bar Plot)
plt.figure(figsize=(10, 6))
sns.barplot(x='transmission', y='price', data=df_cars, estimator=np.mean)
plt.title('Precio Promedio según Tipo de Transmisión')
plt.xlabel('Transmisión')
plt.ylabel('Precio Promedio')
plt.show()
# Out:
# <ipython-input-60-c77694664ea8>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='transmission', y='price', data=df_cars, palette='Set2')

# %% [markdown]
# Diferencias de Precio: La transmisión automática muestra precios significativamente más altos, puede concluir que los autos automáticos son percibidos como más valiosos o que su fabricación es más costosa.
#
# Distribución de Precios: El boxplot permite ver QUE  hay mayor variabilidad en los precios de los autos automáticos en comparación con los manuales.

# %% [markdown]
# Combustible segun el tamaño del motor y precio

# %%
# Scatter plot con tres variables: tamaño del motor, precio y tipo de combustible
plt.figure(figsize=(12, 8))
sns.scatterplot(x='engineSize', y='price', hue='fuelType', data=df_cars, alpha=0.7)
plt.title('Relación entre Tamaño del Motor, Precio y Tipo de Combustible')
plt.xlabel('Tamaño del Motor')
plt.ylabel('Precio')
plt.grid(True)
plt.show()

# Bar plot para el precio promedio por tipo de combustible
plt.figure(figsize=(10, 6))
sns.barplot(x='fuelType', y='price', data=df_cars, estimator=np.mean)
plt.title('Precio Promedio según Tipo de Combustible')
plt.xlabel('Tipo de Combustible')
plt.ylabel('Precio Promedio')
plt.show()

# %% [markdown]
# Influencia del Tamaño del Motor: los gráficos muestran que los autos con motores más grandes tienden a ser más caros, esto confirmaría que el tamaño del motor es un factor importante en el precio del vehículo.
#
# Impacto del Tipo de Combustible: los autos que usan combustible más caro (como diésel) también tienen precios más altos, lo que podría indicar una relación entre el tipo de combustible y el valor percibido del vehículo.
