# %% [markdown]
# <a href="https://colab.research.google.com/github/Oscar52analitica/Data_science_Coder_Oscar_Camargo/blob/main/Copia_de_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/gdrve/')


import pandas as pd

datos = pd.read_excel('/gdrve/MyDrive/Ejercicios_Prueba_Python/a.gsheet')
Nombres = datos['Nombre']

# %%
a=10
b=0.6
c='leo'
list_1= [a,b,c]
print(list_1)
len(list_1)
# Out:
# [10, 0.6, 'leo']
# 3

# %%
type(list_1)
# Out:
# list

# %%
list_1[0]=55
list_1[2]=55
print(list_1[0])
print(list_1[1])
print(list_1[2])
# Out:
# 55
# 0.6
# 55

# %% [markdown]
# ## Tuple

# %%
tuple_1= (1,2,3)
print(tuple_1[1])
# Out:
# 2

# %% [markdown]
# ## Set

# %%
set_1={1,2,3,4,6,5}
type(set_1)
print(set_1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
dic_1={'leo':37, 'Juan':35, 'pepe':33}
type(dic_1)
# Out:
# dict

# %%
dic_1.keys()
dic_1.values()
dic_1.items()
# Out:
# dict_items([('leo', 37), ('Juan', 35), ('pepe', 33)])

# %% [markdown]
# ## for

# %%
for i in range(1,10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in [1,4,6,2]:
  print(i)
# Out:
# 1
# 4
# 6
# 2

# %%
i=1
while i<10:
  print(i)
  i +=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
lista = [20,60,40,80,60,50,10]

# suma y promedio de los elementos de la lista

average = sum(lista)/len(lista)
print(average)
# Out:
# 45.714285714285715

# %%
for i in [20,60,40,80,60,50,10]:
  print(i)
  i +=1
# Out:
# 20
# 60
# 40
# 80
# 60
# 50
# 10

# %%
lista = [20, 60, 40, 80, 60, 50, 10]
suma = 0
cont = 0

for numero in lista:
    suma += numero
    cont += 1

prom = suma / cont
print("Promedio:", prom)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80

# %%
import pandas as pd

Numeros=range(50,70,2)
Numeros_Serie=pd.Series(Numeros)
print(Numeros_Serie)
# Out:
# 0    50
# 1    52
# 2    54
# 3    56
# 4    58
# 5    60
# 6    62
# 7    64
# 8    66
# 9    68
# dtype: int64

# %%
import pandas as pd

Numeros=range(50,70,2)
Numeros_texto=['Primero','Segundo','Tercero','Cuarto','Quinto','Sexto','Septimo','Octovo','Noveno','Decimo']
Numeros_Series_2=pd.Series(Numeros, index=Numeros_texto)
print(Numeros_Series_2)
# Out:
# Primero    50
# Segundo    52
# Tercero    54
# Cuarto     56
# Quinto     58
# Sexto      60
# Septimo    62
# Octovo     64
# Noveno     66
# Decimo     68
# dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

folder_path = '/content/drive/My Drive/Colab Notebooks'
files = os.listdir(folder_path)

for file in files:
    print(file)
# Out:
# Untitled0.ipynb
# Copia de Untitled0.ipynb
# pokemon_data.txt
# defaultoutput.xlsx
# mushroom.csv

# %%
from google.colab import drive
import pandas as pd
import os

# Especificar la ruta de la carpeta
folder_path = '/content/drive/My Drive/Colab Notebooks'

# Leer los archivos en DataFrames específicos
df_pokemon = pd.read_csv(os.path.join(folder_path, 'pokemon_data.txt'), delimiter='\t')
df_mushroom = pd.read_csv(os.path.join(folder_path, 'mushroom.csv'), delimiter=',')
df_defaultoutput = pd.read_excel(os.path.join(folder_path, 'defaultoutput.xlsx'))

# Mostrar las primeras filas de cada DataFrame para verificar
print("Pokemon DataFrame:")
print(df_pokemon.head())
print(df_pokemon.info())

print("\nMushroom DataFrame:")
print(df_mushroom.head())

print("\nDefault Output DataFrame:")
print(df_defaultoutput.head())

# Utilizar metodo describe

descripcion_pokemon = df_pokemon.describe()
print("\nDescripción del DataFrame Pokemon:")
print(descripcion_pokemon)

descripcion_mushroom = df_mushroom.describe()
print("\nDescripción del DataFrame Mushroom:")
print(descripcion_mushroom)

descripcion_defaultoutput = df_defaultoutput.describe()
print("\nDescripción del DataFrame Default Output:")
print(descripcion_defaultoutput)

#  Metodo group by

grouped = df_pokemon.groupby('Type 1').agg({
    'HP': 'mean',
    'Attack': 'mean',
    'Defense': 'mean',
    'Sp. Atk': 'mean'
})

print("\nPromedio de Estadísticas por Tipo:")
print(grouped)
# Out:
# Pokemon DataFrame:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
# ...

# %% [markdown]
# # Sección nueva
